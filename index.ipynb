# %% [markdown]
# # Data Visualization - Lab
#
# ## Introduction
# This lab will give you some structured practice working with the concepts introduced in the previous lesson.
#
# ## Objectives
# You will be able to:
# * Understand matplotlib plot structure for drawing basic plots.
# * Visualize data using scatterplots, barplots and histograms
#
# ## Exercise 1
#
# Make a vertical bar graph using `plt.bar()` for the following set of data:
#
# >Jim's Video Library contains 40 crime/mystery, 30 science fiction, 10 drama, 50 comedy, 25 action and 5 documentary movies.
#
# * Set a figure size of 8x6 inches
# * Set x-axis (genres) and y-axis (number of movies)
# * Plot and label the bar graph
# * Provide a suitable title
# * Label x and y-axis

# %%
# import the required libraries
import numpy as np
import matplotlib.pyplot as plt

y = [40, 30, 10, 50, 25, 5]
x = np.arange(len(y))
labels = ['Crime', 'Sci/fi', 'Drama', 'Comedy', 'Action', 'Doc']
plt.figure(figsize=(8,6))
plt.bar(x,y, label='book collection')
plt.title('Jim\'s Video Library')
plt.xlabel('Genres')
plt.ylabel('Number of Movies')
plt.xticks(x, labels)
plt.legend()
plt.show()
# Set a figure size

# Plot vertical bars of fixed width by passing x and y values to .bar() function 

# Give a title to the bar graph

# Output the final plot

# %%
y = [13,24,26,9,5,18]
x = np.arange(len(y))
labels = ['Crime','Sci/Fi','Drama','Poet','Doc','History']
plt.figure(figsize=(8,6))
plt.bar(x,y)
plt.title("Jim's Book Collection")
plt.xlabel('Genres')
plt.ylabel('Number of Books')
plt.xticks(x, labels)
plt.show()

# %%
y = [13,24,26,9,5,18]
x = np.arange(len(y))
labels = ['Crime', 'Sci/Fic', 'Drama', 'Poet', 'Doc', 'History']
plt.figure(figsize=(8,6))
plt.bar(x,y)
plt.title("Jim's Book Library")
plt.xlabel('Genres')
plt.ylabel('Number of Books')
plt.xticks(x, labels)
plt.show()

# %%
y = [13,24,26,9,5,18]
x = np.arange(len(y))
labels = ('Crime','Sci/Fic','Drama','Poet','Doc','History')
plt.figure(figsize=(8,6))
plt.bar(x,y)
plt.xlabel('Genres')
plt.ylabel('Number of Books')
plt.xticks(x, labels)
plt.show()

# %%
y = [13,24,26,9,5,18]
x = np.arange(len(y))
labels = ('Crime','Sci/Fic','Drama','Poet','Doc','History')
plt.figure(figsize=(8,6))
plt.bar(x,y)
plt.title('Jim\'s Book Library')
plt.xlabel('Genres')
plt.ylabel('Number of Books')
plt.show()

# %%
weight = [2750, 3125, 2100, 4082, 2690, 3640, 4380, 2241, 2895, 3659]
mpg = [29, 23, 33, 28, 20, 21, 14, 25, 31, 17]

# Set the figure size in inches
plt.figure(figsize=(8,6))

# Plot with scatter()
plt.scatter(weight, mpg,label='weight vs.mileage')
plt.title('Consumer Cars')
plt.xlabel('Car Weight')
plt.ylabel('Miles per galon')
plt.legend()
plt.show()
# Plot with scatter()
plt.xlabel('Car Weigh')
plt.ylabel('Miles per Galon')
plt.legend()
plt.show()
# Set x and y axes labels and give titles

# %% [markdown]
# ## Exercise 3
#
# Joe is the branch manager at a bank. Recently, Joe been receiving customer feedback saying that the waiting times for a client to be served by a customer service representative are too long. Joe decides to observe and write down the time spent by each customer on waiting. Here are his findings from observing and writing down the wait times (in seconds), spent by 20 customers:
#
# 43.1, 35.6, 37.5, 36.5, 45.3, 43.4, 40.3, 50.2, 47.3, 31.2, 42.2, 45.5, 30.3, 31.4, 35.6, 45.2, 54.1, 45.6, 36.5, 43.1
#
# * Build a histogram of these values using the `hist()` function
# * Plot, label and give a title as above. Use  `bins=5`
# * Briefly describe the output in terms of waiting times.

# %%
x = [43.1, 35.6, 37.5, 36.5, 45.3, 43.4, 40.3, 50.2, 47.3, 31.2, 42.2, 45.5, 30.3, 31.4, 35.6, 45.2, 54.1, 45.6, 36.5, 43.1]
plt.figure(figsize=(8,6))
plt.hist(x, bins=5)
plt.title('Consumer Waiting Time')
plt.xlabel('Waiting Time')
plt.ylabel('Number of Customers')
plt.show()

# %%
x = [43.1, 35.6, 37.5, 36.5, 45.3, 43.4, 40.3, 50.2, 47.3, 31.2, 42.2, 45.5, 30.3, 31.4, 35.6, 45.2, 54.1, 45.6, 36.5, 43.1]

#Plot the distogram with hist() function
plt.hist(x, bins=5, label='Customer Serving Period')
plt.figure(figsize=(8,6))
# Label, give title and show the plot
plt.title('Customer Waiting Time')
plt.xlabel('Waiting Time')
plt.ylabel('Number of Customers')
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# ## Summary
#
# Hopefully this lab has given you some good practice working with creating plots in Python using Matplotlib.
